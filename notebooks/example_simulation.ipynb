# %% [markdown]
# ---
# exports:
#   - format: pdf
#     template: lapreprint-typst
#     output: exports/example-simulation-page.pdf
#     id: example-simulation-page-pdf
# downloads:
#   - id: example-simulation-page-pdf
#     title: Download This Page (PDF)
#   - id: full-book-pdf
#     title: Download Full Book PDF
# ---
# # Example Simulation
#
# +++ {"part": "abstract"}
# This notebook demonstrates a simple calculation.
# +++

# %%
print("Hello, Building Science Atlas!")

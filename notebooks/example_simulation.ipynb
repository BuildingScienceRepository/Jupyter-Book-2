# %% [markdown]
# ---
# exports:
#   - format: pdf
#     id: example-simulation-pdf
# downloads:
#   - id: example-simulation-pdf
#     title: Download PDF
# ---
#
# # Example Simulation
#
# This notebook demonstrates a simple calculation.

# %%
print("Hello, Building Science Atlas!")
